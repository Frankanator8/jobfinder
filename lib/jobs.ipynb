# %%
import csv
from jobspy import scrape_jobs
import pandas as pd

# swe, healthcare

jobs = scrape_jobs(
    site_name=["indeed", "linkedin", "zip_recruiter", "google"], # "glassdoor", "bayt", "naukri", "bdjobs"
    search_term="software engineering",
    google_search_term="software engineering AI startup jobs near San Francisco, CA since yesterday",
    location="San Francisco, CA",
    results_wanted=10,
    hours_old=24,
    country_indeed='USA',
    
    linkedin_fetch_description=True # gets more info such as description, direct job url (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
)
print(f"Found {len(jobs)} jobs")
p = pd.DataFrame(jobs)["job_url_direct"]
# Out:
# Found 20 jobs

# %%
p
# Out:
# 0     https://careers.usbank.com/global/en/job/UBNAG...
# 1     https://click.appcast.io/t/TDGmppb8pWsil6ultj4...
# 2     https://click.appcast.io/t/JCDVtrtglI1X8udHt0O...
# 3     https://jobs.ashbyhq.com/metriport/cde549d5-31...
# 4     https://jobs.ashbyhq.com/metriport/4d52f0cf-86...
# 5     https://jobs.ashbyhq.com/metriport/796b8e15-c2...
# 6     https://click.appcast.io/t/49H-LS_qg2jiquk1DqA...
# 7     https://click.appcast.io/t/n49OtDNBro_-3lUKoEq...
# 8     https://click.appcast.io/t/sMwCZ6QQ-784-UwqrB3...
# 9     https://click.appcast.io/t/4KLi_rRxCQnLKHHvQoK...
# 10    https://jobs.ashbyhq.com/GigaML/cb74c445-322b-...
# 11    https://jobs.ashbyhq.com/openai/77bc0b3a-35c1-...
# 12    https://app.dover.com/apply/tiki-ai/fdf1acb8-d...
# 13                                                  NaN
# 14    https://tnl2.jometer.com/v2/job?jz=5wqzs57e83e...
# 15    https://lensa.com/cgw/6c9c09bc71b846da88e9ceda...
# 16    https://stripe.com/jobs/listing/software-engin...
# 17    https://nuro.ai/careersitem?gh_jid=7532060&gh_...
# 18    https://job-boards.greenhouse.io/twitch/jobs/8...
# 19                                                  NaN
# Name: job_url_direct, dtype: object

# %%
p[12]
# Out:
# 'https://app.dover.com/apply/tiki-ai/fdf1acb8-dabe-4549-a733-7ba957b40c62?rs=42706078&urlHash=t0ov'
